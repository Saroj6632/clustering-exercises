# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import env
import os
pd.set_option('display.max_columns', None)

# %%
# function to establish connection to MySQL workbench to retrieve data.
def get_connection(db, user=env.username, host=env.host, password=env.password):
    return f'mysql+pymysql://{env.username}:{env.password}@{env.host}/{db}'

# %%
def new_zillow_data():
    sql_querry= '''
            select *
            from properties_2017
            right join predictions_2017  using(parcelid)
            WHERE transactiondate < '2018'
                  
            '''
    
    
    df= pd.read_sql(sql_querry, get_connection('zillow'))
    df= df.drop(columns='id')
    df= df.drop_duplicates(subset=['parcelid'],keep='last')
    return df

# %%
def zillow_data():
    '''this function returns the zillow data and creates the csv file in local directory  if it doesnot exist already.'''
    filename= "zillow.csv"
    if os.path.isfile(filename):
        return pd.read_csv(filename)
    else:
        # read data from database in dataframe
        df= new_zillow_data()
        #cache data
        df.to_csv(filename)
        return df

# %%
df= zillow_data()
df.head()
# Out:
#    parcelid  logerror transactiondate  airconditioningtypeid  \
# 0  14297519  0.025595      2017-01-01                    NaN
# 1  17052889  0.055619      2017-01-01                    NaN
# 2  14186244  0.005383      2017-01-01                    NaN
# 3  12177905 -0.103410      2017-01-01                    NaN
# 4  10887214  0.006940      2017-01-01                    1.0
#
#    architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 0                       NaN           NaN          3.5         4.0
# 1                       NaN           NaN          1.0         2.0
# 2                       NaN           NaN          2.0         3.0
# 3                       NaN           NaN          3.0         4.0
# 4                       NaN           NaN          3.0         3.0
#
#    buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  decktypeid  \
# 0                  NaN                    NaN                3.5         NaN
# 1                  NaN                    NaN                1.0         NaN
# 2                  NaN                    NaN                2.0         NaN
# 3                  NaN                    8.0                3.0         NaN
# 4                  NaN                    8.0                3.0         NaN
#
#    finishedfloor1squarefeet  calculatedfinishedsquarefeet  \
# 0                       NaN                        3100.0
# 1                    1465.0                        1465.0
# 2                       NaN                        1243.0
# 3                       NaN                        2376.0
# 4                       NaN                        1312.0
#
#    finishedsquarefeet12  finishedsquarefeet13  finishedsquarefeet15  \
# 0                3100.0                   NaN                   NaN
# 1                1465.0                   NaN                   NaN
# 2                1243.0                   NaN                   NaN
# 3                2376.0                   NaN                   NaN
# 4                1312.0                   NaN                   NaN
#
#    finishedsquarefeet50  finishedsquarefeet6    fips  fireplacecnt  \
# 0                   NaN                  NaN  6059.0           NaN
# 1                1465.0                  NaN  6111.0           1.0
# 2                   NaN                  NaN  6059.0           NaN
# 3                   NaN                  NaN  6037.0           NaN
# 4                   NaN                  NaN  6037.0           NaN
#
#    fullbathcnt  garagecarcnt  garagetotalsqft  hashottuborspa  \
# 0          3.0           2.0            633.0             NaN
# 1          1.0           1.0              0.0             NaN
# 2          2.0           2.0            440.0             NaN
# 3          3.0           NaN              NaN             NaN
# 4          3.0           NaN              NaN             NaN
#
#    heatingorsystemtypeid    latitude    longitude  lotsizesquarefeet  poolcnt  \
# 0                    NaN  33634931.0 -117869207.0             4506.0      NaN
# 1                    NaN  34449266.0 -119281531.0            12647.0      NaN
# 2                    NaN  33886168.0 -117823170.0             8432.0      1.0
# 3                    2.0  34245180.0 -118240722.0            13038.0      1.0
# 4                    2.0  34185120.0 -118414640.0           278581.0      1.0
#
#    poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# 0          NaN           NaN          NaN          NaN
# 1          NaN           NaN          NaN          NaN
# 2          NaN           NaN          NaN          1.0
# 3          NaN           NaN          NaN          1.0
# 4          NaN           NaN          NaN          1.0
#
#   propertycountylandusecode  propertylandusetypeid propertyzoningdesc  \
# 0                       122                  261.0               None
# 1                      1110                  261.0               None
# 2                       122                  261.0               None
# 3                      0101                  261.0         LCR110000*
# 4                      010C                  266.0               LAR3
#
#    rawcensustractandblock  regionidcity  regionidcounty  regionidneighborhood  \
# 0            6.059063e+07       53571.0          1286.0                   NaN
# 1            6.111001e+07       13091.0          2061.0                   NaN
# 2            6.059022e+07       21412.0          1286.0                   NaN
# 3            6.037300e+07      396551.0          3101.0                   NaN
# 4            6.037124e+07       12447.0          3101.0              268548.0
#
#    regionidzip  roomcnt  storytypeid  threequarterbathnbr  \
# 0      96978.0      0.0          NaN                  1.0
# 1      97099.0      5.0          NaN                  NaN
# 2      97078.0      6.0          NaN                  NaN
# 3      96330.0      0.0          NaN                  NaN
# 4      96451.0      0.0          NaN                  NaN
#
#    typeconstructiontypeid  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 0                     NaN      NaN                 NaN                 NaN
# 1                     NaN      NaN                 NaN                 NaN
# 2                     NaN      NaN                 NaN                 NaN
# 3                     NaN      1.0                 NaN                 NaN
# 4                     NaN      1.0                 NaN                 NaN
#
#    yearbuilt  numberofstories  fireplaceflag  structuretaxvaluedollarcnt  \
# 0     1998.0              NaN            NaN                    485713.0
# 1     1967.0              1.0            NaN                     88000.0
# 2     1962.0              1.0            NaN                     85289.0
# 3     1970.0              NaN            NaN                    108918.0
# 4     1964.0              NaN            NaN                     73681.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0          1023282.0          2016.0               537569.0   11013.72
# 1           464000.0          2016.0               376000.0    5672.48
# 2           564778.0          2016.0               479489.0    6488.30
# 3           145143.0          2016.0                36225.0    1777.51
# 4           119407.0          2016.0                45726.0    1533.89
#
#   taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 0               None                 NaN         6.059063e+13
# 1               None                 NaN         6.111001e+13
# 2               None                 NaN         6.059022e+13
# 3               None                 NaN         6.037300e+13
# 4               None                 NaN         6.037124e+13

# %%
#shape of the dataframe
df.shape
# Out:
# (77414, 60)

# %% [markdown]
# # Summarize your data (summary stats, info, dtypes, shape, distributions, value_counts, etc.)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77414 entries, 0 to 77612
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      77414 non-null  int64
#  1   logerror                      77414 non-null  float64
#  2   transactiondate               77414 non-null  object
#  3   airconditioningtypeid         24953 non-null  float64
#  4   architecturalstyletypeid      206 non-null    float64
#  5   basementsqft                  50 non-null     float64
#  6   bathroomcnt                   77381 non-null  float64
#  7   bedroomcnt                    77381 non-null  float64
#  8   buildingclasstypeid           15 non-null     float64
#  9   buildingqualitytypeid         49672 non-null  float64
#  10  calculatedbathnbr             76772 non-null  float64
#  11  decktypeid                    614 non-null    float64
#  12  finishedfloor1squarefeet      6023 non-null   float64
#  13  calculatedfinishedsquarefeet  77185 non-null  float64
#  14  finishedsquarefeet12          73749 non-null  float64
#  15  finishedsquarefeet13          41 non-null     float64
#  16  finishedsquarefeet15          3009 non-null   float64
#  17  finishedsquarefeet50          6023 non-null   float64
#  18  finishedsquarefeet6           386 non-null    float64
#  19  fips                          77381 non-null  float64
#  20  fireplacecnt                  8276 non-null   float64
#  21  fullbathcnt                   76772 non-null  float64
#  22  garagecarcnt                  25474 non-null  float64
#  23  garagetotalsqft               25474 non-null  float64
#  24  hashottuborspa                1538 non-null   float64
#  25  heatingorsystemtypeid         49440 non-null  float64
#  26  latitude                      77381 non-null  float64
#  27  longitude                     77381 non-null  float64
#  28  lotsizesquarefeet             69142 non-null  float64
#  29  poolcnt                       16137 non-null  float64
#  30  poolsizesum                   867 non-null    float64
#  31  pooltypeid10                  464 non-null    float64
#  32  pooltypeid2                   1074 non-null   float64
#  33  pooltypeid7                   15042 non-null  float64
#  34  propertycountylandusecode     77381 non-null  object
#  35  propertylandusetypeid         77381 non-null  float64
#  36  propertyzoningdesc            50331 non-null  object
#  37  rawcensustractandblock        77381 non-null  float64
#  38  regionidcity                  75910 non-null  float64
#  39  regionidcounty                77381 non-null  float64
#  40  regionidneighborhood          30890 non-null  float64
#  41  regionidzip                   77331 non-null  float64
#  42  roomcnt                       77381 non-null  float64
#  43  storytypeid                   50 non-null     float64
#  44  threequarterbathnbr           10096 non-null  float64
#  45  typeconstructiontypeid        222 non-null    float64
#  46  unitcnt                       50563 non-null  float64
#  47  yardbuildingsqft17            2388 non-null   float64
#  48  yardbuildingsqft26            70 non-null     float64
#  49  yearbuilt                     77118 non-null  float64
#  50  numberofstories               17560 non-null  float64
#  51  fireplaceflag                 172 non-null    float64
#  52  structuretaxvaluedollarcnt    77269 non-null  float64
#  53  taxvaluedollarcnt             77380 non-null  float64
#  54  assessmentyear                77381 non-null  float64
#  55  landtaxvaluedollarcnt         77379 non-null  float64
#  56  taxamount                     77376 non-null  float64
#  57  taxdelinquencyflag            2886 non-null   object
#  58  taxdelinquencyyear            2886 non-null   float64
#  59  censustractandblock           77137 non-null  float64
# dtypes: float64(55), int64(1), object(4)
# memory usage: 36.0+ MB

# %%
df.describe()
# Out:
#            parcelid  airconditioningtypeid  architecturalstyletypeid  \
# count  5.232000e+04           13615.000000                  70.00000
# mean   1.299682e+07               2.439589                   7.10000
# std    3.350919e+06               3.847925                   2.66567
# min    1.071186e+07               1.000000                   2.00000
# 25%    1.151018e+07               1.000000                   7.00000
# 50%    1.257829e+07               1.000000                   7.00000
# 75%    1.413036e+07               1.000000                   7.00000
# max    1.676878e+08              13.000000                  21.00000
#
#        basementsqft   bathroomcnt    bedroomcnt  buildingqualitytypeid  \
# count     47.000000  52320.000000  52320.000000           33655.000000
# mean     678.978723      2.300010      3.300765               6.264894
# std      711.825226      1.022807      0.947555               1.716346
# min       38.000000      0.000000      0.000000               1.000000
# 25%      263.500000      2.000000      3.000000               5.000000
# 50%      512.000000      2.000000      3.000000               6.000000
# 75%      809.500000      3.000000      4.000000               8.000000
# max     3560.000000     18.000000     14.000000              12.000000
#
#        calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# count       52185.000000       389.0               4371.000000
# mean            2.305270        66.0               1546.288035
# std             1.018067         0.0                675.339282
# min             1.000000        66.0                184.000000
# 25%             2.000000        66.0               1151.000000
# 50%             2.000000        66.0               1410.000000
# 75%             3.000000        66.0               1760.000000
# max            18.000000        66.0               6912.000000
#
#        calculatedfinishedsquarefeet  finishedsquarefeet12  \
# count                  52239.000000          52074.000000
# mean                    1923.152702           1925.313899
# std                     1004.045419           1003.952951
# min                      128.000000            128.000000
# 25%                     1268.000000           1270.000000
# 50%                     1659.000000           1661.000000
# 75%                     2306.000000           2309.000000
# max                    21929.000000          21929.000000
#
#        finishedsquarefeet50  finishedsquarefeet6         fips  fireplacecnt  \
# count           4371.000000           165.000000  52320.00000   7233.000000
# mean            1567.099291          1241.078788   6049.13555      1.209733
# std              745.084810           776.959074     21.02913      0.512946
# min              184.000000           380.000000   6037.00000      1.000000
# 25%             1152.000000           784.000000   6037.00000      1.000000
# 50%             1415.000000          1008.000000   6037.00000      1.000000
# 75%             1771.000000          1320.000000   6059.00000      1.000000
# max            12467.000000          5598.000000   6111.00000      5.000000
#
#         fullbathcnt  garagecarcnt  garagetotalsqft  hashottuborspa  \
# count  52185.000000  17984.000000     17984.000000          1514.0
# mean       2.240031      1.949066       495.927046             1.0
# std        0.993303      0.549974       157.100947             0.0
# min        1.000000      0.000000         0.000000             1.0
# 25%        2.000000      2.000000       426.000000             1.0
# 50%        2.000000      2.000000       462.000000             1.0
# 75%        3.000000      2.000000       567.000000             1.0
# max       18.000000     14.000000      4251.000000             1.0
#
#        heatingorsystemtypeid      latitude     longitude  lotsizesquarefeet  \
# count           33850.000000  5.232000e+04  5.232000e+04       5.195400e+04
# mean                3.965613  3.402256e+07 -1.181941e+08       1.132335e+04
# std                 2.562660  2.740624e+05  3.567149e+05       8.674164e+04
# min                 1.000000  3.334062e+07 -1.194754e+08       2.360000e+02
# 25%                 2.000000  3.382690e+07 -1.184009e+08       5.583000e+03
# 50%                 2.000000  3.402375e+07 -1.181531e+08       6.841000e+03
# 75%                 7.000000  3.418725e+07 -1.179290e+08       8.799000e+03
# max                24.000000  3.481877e+07 -1.175546e+08       6.971010e+06
#
#        poolcnt  poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# count  11077.0   865.000000         443.0       1071.0       9990.0
# mean       1.0   518.305202           1.0          1.0          1.0
# std        0.0   156.614794           0.0          0.0          0.0
# min        1.0    24.000000           1.0          1.0          1.0
# 25%        1.0   424.000000           1.0          1.0          1.0
# 50%        1.0   500.000000           1.0          1.0          1.0
# 75%        1.0   600.000000           1.0          1.0          1.0
# max        1.0  1500.000000           1.0          1.0          1.0
#
#        propertylandusetypeid  rawcensustractandblock   regionidcity  \
# count                52320.0            5.232000e+04   51284.000000
# mean                   261.0            6.049447e+07   33483.826691
# std                      0.0            2.086892e+05   49116.149883
# min                    261.0            6.037101e+07    3491.000000
# 25%                    261.0            6.037401e+07   12447.000000
# 50%                    261.0            6.037620e+07   24812.000000
# 75%                    261.0            6.059042e+07   40227.000000
# max                    261.0            6.111009e+07  396556.000000
#
#        regionidcounty  regionidneighborhood    regionidzip       roomcnt  \
# count    52320.000000          18981.000000   52294.000000  52320.000000
# mean      2524.320623         180240.600232   96636.243603      1.894457
# std        804.098580         159928.810868    4610.382493      3.146952
# min       1286.000000           6952.000000   95982.000000      0.000000
# 25%       1286.000000          41131.000000   96206.000000      0.000000
# 50%       3101.000000         118208.000000   96412.000000      0.000000
# 75%       3101.000000         274514.000000   96995.000000      5.000000
# max       3101.000000         764167.000000  399675.000000     15.000000
#
#        storytypeid  threequarterbathnbr  typeconstructiontypeid       unitcnt  \
# count         47.0          6717.000000               76.000000  33762.000000
# mean           7.0             1.013697                5.973684      1.000859
# std            0.0             0.142690                0.229416      0.030290
# min            7.0             1.000000                4.000000      1.000000
# 25%            7.0             1.000000                6.000000      1.000000
# 50%            7.0             1.000000                6.000000      1.000000
# 75%            7.0             1.000000                6.000000      1.000000
# max            7.0             7.000000                6.000000      3.000000
#
#        yardbuildingsqft17  yardbuildingsqft26     yearbuilt  numberofstories  \
# count         1935.000000           63.000000  52206.000000     14532.000000
# mean           337.359690          225.619048   1963.421254         1.414189
# std            249.579315          188.505106     23.125670         0.540685
# min             11.000000           12.000000   1878.000000         1.000000
# 25%            200.000000           71.500000   1950.000000         1.000000
# 50%            280.000000          180.000000   1961.000000         1.000000
# 75%            400.000000          317.000000   1979.000000         2.000000
# max           3191.000000          868.000000   2016.000000         6.000000
#
#        fireplaceflag  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# count           81.0                5.223800e+04       5.231900e+04
# mean             1.0                1.966362e+05       5.298235e+05
# std              0.0                2.542862e+05       7.518296e+05
# min              1.0                1.290000e+02       1.000000e+03
# 25%              1.0                7.715900e+04       1.940330e+05
# 50%              1.0                1.319050e+05       3.740060e+05
# 75%              1.0                2.264532e+05       6.193540e+05
# max              1.0                9.164901e+06       4.906124e+07
#
#        assessmentyear  landtaxvaluedollarcnt      taxamount  \
# count         52320.0           5.231900e+04   52316.000000
# mean           2016.0           3.334917e+05    6454.743137
# std               0.0           5.705106e+05    8752.477267
# min            2016.0           1.610000e+02      49.180000
# 25%            2016.0           7.619400e+04    2660.982500
# 50%            2016.0           2.180790e+05    4650.565000
# 75%            2016.0           4.087770e+05    7379.270000
# max            2016.0           4.895220e+07  586639.300000
#
#        taxdelinquencyyear  censustractandblock      logerror
# count         2068.000000         5.219900e+04  52320.000000
# mean            14.101064         6.050245e+13      0.018131
# std              2.400399         1.861127e+12      0.176905
# min              4.000000         6.037101e+13     -4.655420
# 25%             14.000000         6.037401e+13     -0.024707
# 50%             15.000000         6.037620e+13      0.006934
# 75%             15.000000         6.059042e+13      0.040597
# max             99.000000         4.830301e+14      5.262999

# %%
# value counts for each colummn in the dataframe
for col in df.columns:
    print(col)
    print(df[col].value_counts())
# Out:
# parcelid
# 14297519    1
# 12895331    1
# 12680821    1
# 11839030    1
# 17148095    1
#            ..
# 17294679    1
# 14138000    1
# 12026029    1
# 14212835    1
# 12826780    1
# Name: parcelid, Length: 52320, dtype: int64
# airconditioningtypeid
# 1.0     11873
# 13.0     1567
# 5.0       159
# 11.0       16
# Name: airconditioningtypeid, dtype: int64
# architecturalstyletypeid
# 7.0     62
# 3.0      3
# 2.0      2
# 21.0     2
# 8.0      1
# Name: architecturalstyletypeid, dtype: int64
# basementsqft
# 900.0     2
# 640.0     2
# 100.0     2
# 515.0     2
# 273.0     2
# 912.0     2
# 314.0     1
# 819.0     1
# 1809.0    1
# 604.0     1
# 126.0     1
# 588.0     1
# 786.0     1
# 669.0     1
# 800.0     1
# 396.0     1
# 112.0     1
# 645.0     1
# 384.0     1
# 1969.0    1
# 252.0     1
# 600.0     1
# 1218.0    1
# 280.0     1
# 300.0     1
# 224.0     1
# 512.0     1
# 380.0     1
# 204.0     1
# 200.0     1
# 90.0      1
# 3112.0    1
# 405.0     1
# 1252.0    1
# 254.0     1
# 3560.0    1
# 352.0     1
# 168.0     1
# 394.0     1
# 1416.0    1
# 38.0      1
# Name: basementsqft, dtype: int64
# bathroomcnt
# 2.0     21840
# 3.0     10650
# 1.0      9536
# 2.5      3932
# 4.0      2225
# 3.5       916
# 1.5       839
# 5.0       803
# 4.5       686
# 6.0       320
# 5.5       224
# 0.0       119
# 7.0        88
# 8.0        53
# 6.5        47
# 7.5        16
# 9.0        13
# 10.0        5
# 11.0        3
# 8.5         3
# 18.0        1
# 13.0        1
# Name: bathroomcnt, dtype: int64
# bedroomcnt
# 3.0     23303
# 4.0     15210
# 2.0      8317
# 5.0      3967
# 6.0       634
# 1.0       611
# 0.0       135
# 7.0       106
# 8.0        24
# 9.0         8
# 10.0        2
# 14.0        1
# 11.0        1
# 12.0        1
# Name: bedroomcnt, dtype: int64
# buildingclasstypeid
# Series([], Name: buildingclasstypeid, dtype: int64)
# buildingqualitytypeid
# 6.0     10260
# 8.0      8222
# 4.0      8136
# 7.0      3424
# 5.0      1507
# 9.0      1119
# 11.0      514
# 10.0      230
# 3.0       149
# 12.0       81
# 1.0         8
# 2.0         5
# Name: buildingqualitytypeid, dtype: int64
# calculatedbathnbr
# 2.0     21840
# 3.0     10650
# 1.0      9536
# 2.5      3924
# 4.0      2225
# 3.5       916
# 1.5       832
# 5.0       803
# 4.5       686
# 6.0       320
# 5.5       223
# 7.0        88
# 8.0        53
# 6.5        47
# 7.5        16
# 9.0        13
# 10.0        5
# 11.0        3
# 8.5         3
# 18.0        1
# 13.0        1
# Name: calculatedbathnbr, dtype: int64
# decktypeid
# 66.0    389
# Name: decktypeid, dtype: int64
# finishedfloor1squarefeet
# 1252.0    22
# 1205.0    21
# 1462.0    21
# 1227.0    19
# 1431.0    17
#           ..
# 1708.0     1
# 922.0      1
# 2062.0     1
# 4300.0     1
# 2652.0     1
# Name: finishedfloor1squarefeet, Length: 1553, dtype: int64
# calculatedfinishedsquarefeet
# 1120.0    128
# 1200.0    118
# 1080.0    101
# 1040.0     86
# 936.0      86
#          ...
# 9843.0      1
# 7088.0      1
# 604.0       1
# 5422.0      1
# 5655.0      1
# Name: calculatedfinishedsquarefeet, Length: 4723, dtype: int64
# finishedsquarefeet12
# 1120.0    127
# 1200.0    117
# 1080.0    101
# 936.0      86
# 1040.0     85
#          ...
# 7088.0      1
# 604.0       1
# 5422.0      1
# 534.0       1
# 5655.0      1
# Name: finishedsquarefeet12, Length: 4716, dtype: int64
# finishedsquarefeet13
# Series([], Name: finishedsquarefeet13, dtype: int64)
# finishedsquarefeet15
# Series([], Name: finishedsquarefeet15, dtype: int64)
# finishedsquarefeet50
# 1252.0    22
# 1205.0    21
# 1462.0    21
# 1227.0    19
# 1431.0    17
#           ..
# 1533.0     1
# 1708.0     1
# 922.0      1
# 2062.0     1
# 2652.0     1
# Name: finishedsquarefeet50, Length: 1572, dtype: int64
# finishedsquarefeet6
# 952.0     4
# 520.0     3
# 750.0     2
# 765.0     2
# 845.0     2
#          ..
# 1178.0    1
# 670.0     1
# 748.0     1
# 1200.0    1
# 905.0     1
# Name: finishedsquarefeet6, Length: 155, dtype: int64
# fips
# 6037.0    33824
# 6059.0    14111
# 6111.0     4385
# Name: fips, dtype: int64
# fireplacecnt
# 1.0    6024
# 2.0     942
# 3.0     229
# 4.0      35
# 5.0       3
# Name: fireplacecnt, dtype: int64
# fullbathcnt
# 2.0     25776
# 3.0     11575
# 1.0     10368
# 4.0      2912
# 5.0      1022
# 6.0       357
# 7.0        96
# 8.0        56
# 9.0        13
# 10.0        5
# 11.0        3
# 18.0        1
# 13.0        1
# Name: fullbathcnt, dtype: int64
# garagecarcnt
# 2.0     14777
# 1.0      2197
# 3.0       621
# 4.0       253
# 0.0        65
# 5.0        45
# 6.0        13
# 7.0         3
# 10.0        3
# 8.0         2
# 9.0         2
# 11.0        1
# 13.0        1
# 14.0        1
# Name: garagecarcnt, dtype: int64
# garagetotalsqft
# 400.0     786
# 441.0     678
# 462.0     658
# 360.0     646
# 460.0     569
#          ...
# 1006.0      1
# 275.0       1
# 1056.0      1
# 261.0       1
# 957.0       1
# Name: garagetotalsqft, Length: 839, dtype: int64
# hashottuborspa
# 1.0    1514
# Name: hashottuborspa, dtype: int64
# heatingorsystemtypeid
# 2.0     20689
# 7.0     12527
# 6.0       517
# 20.0       85
# 13.0       16
# 1.0         7
# 18.0        6
# 10.0        2
# 24.0        1
# Name: heatingorsystemtypeid, dtype: int64
# latitude
# 34047500.0    12
# 34487900.0     7
# 33494800.0     7
# 34101300.0     7
# 34041200.0     6
#               ..
# 34185350.0     1
# 34296566.0     1
# 34077240.0     1
# 33853596.0     1
# 33937685.0     1
# Name: latitude, Length: 50478, dtype: int64
# longitude
# -118249000.0    12
# -117835000.0     7
# -117830000.0     7
# -118172000.0     7
# -118327000.0     7
#                 ..
# -117834737.0     1
# -118659512.0     1
# -118132169.0     1
# -117744674.0     1
# -117996709.0     1
# Name: longitude, Length: 50764, dtype: int64
# lotsizesquarefeet
# 6000.0     873
# 5000.0     413
# 7200.0     306
# 7000.0     285
# 6500.0     272
#           ...
# 18024.0      1
# 20673.0      1
# 4775.0       1
# 9367.0       1
# 47405.0      1
# Name: lotsizesquarefeet, Length: 14292, dtype: int64
# poolcnt
# 1.0    11077
# Name: poolcnt, dtype: int64
# poolsizesum
# 450.0     89
# 400.0     38
# 500.0     30
# 600.0     27
# 512.0     25
#           ..
# 275.0      1
# 434.0      1
# 1070.0     1
# 368.0      1
# 780.0      1
# Name: poolsizesum, Length: 262, dtype: int64
# pooltypeid10
# 1.0    443
# Name: pooltypeid10, dtype: int64
# pooltypeid2
# 1.0    1071
# Name: pooltypeid2, dtype: int64
# pooltypeid7
# 1.0    9990
# Name: pooltypeid7, dtype: int64
# propertycountylandusecode
# 0100    26714
# 122     13045
# 0101     6399
# 1111     3353
# 1        1066
# 1110     1024
# 0104      367
# 010G       93
# 0103       91
# 0108       57
# 010M       52
# 0109       18
# 1112        8
# 0110        6
# 0113        6
# 0141        4
# 0102        3
# 0105        3
# 010V        2
# 0111        2
# 0130        2
# 0131        1
# 0133        1
# 0115        1
# 010L        1
# 0114        1
# Name: propertycountylandusecode, dtype: int64
# propertylandusetypeid
# 261.0    52320
# Name: propertylandusetypeid, dtype: int64
# propertyzoningdesc
# LAR1          6480
# LARS          1380
# LBR1N         1109
# SCUR2          712
# LARE11         611
#               ...
# LCR3800015       1
# PSR6*            1
# LARE             1
# MYR3PY           1
# BFA15000*        1
# Name: propertyzoningdesc, Length: 1286, dtype: int64
# rawcensustractandblock
# 6.037920e+07    36
# 6.037920e+07    32
# 6.037142e+07    24
# 6.059032e+07    24
# 6.059032e+07    23
#                 ..
# 6.059075e+07     1
# 6.037504e+07     1
# 6.037540e+07     1
# 6.059099e+07     1
# 6.037503e+07     1
# Name: rawcensustractandblock, Length: 31441, dtype: int64
# regionidcity
# 12447.0    11418
# 5534.0      1791
# 40227.0     1491
# 46298.0     1424
# 16764.0     1085
#            ...
# 32927.0        3
# 31134.0        2
# 36078.0        1
# 10815.0        1
# 21395.0        1
# Name: regionidcity, Length: 175, dtype: int64
# regionidcounty
# 3101.0    33824
# 1286.0    14111
# 2061.0     4385
# Name: regionidcounty, dtype: int64
# regionidneighborhood
# 48570.0     501
# 118208.0    473
# 27080.0     448
# 274049.0    391
# 51906.0     373
#            ...
# 763079.0      1
# 764138.0      1
# 763090.0      1
# 764167.0      1
# 762940.0      1
# Name: regionidneighborhood, Length: 437, dtype: int64
# regionidzip
# 97319.0    776
# 97318.0    670
# 97329.0    563
# 97328.0    519
# 97118.0    497
#           ...
# 96467.0      1
# 97092.0      1
# 96148.0      1
# 96038.0      1
# 97088.0      1
# Name: regionidzip, Length: 381, dtype: int64
# roomcnt
# 0.0     37761
# 6.0      3974
# 7.0      3608
# 8.0      2810
# 5.0      1886
# 9.0      1173
# 4.0       518
# 10.0      338
# 11.0      108
# 3.0        79
# 12.0       35
# 2.0        12
# 13.0       10
# 14.0        6
# 1.0         1
# 15.0        1
# Name: roomcnt, dtype: int64
# storytypeid
# 7.0    47
# Name: storytypeid, dtype: int64
# threequarterbathnbr
# 1.0    6638
# 2.0      70
# 3.0       8
# 7.0       1
# Name: threequarterbathnbr, dtype: int64
# typeconstructiontypeid
# 6.0    75
# 4.0     1
# Name: typeconstructiontypeid, dtype: int64
# unitcnt
# 1.0    33734
# 2.0       27
# 3.0        1
# Name: unitcnt, dtype: int64
# yardbuildingsqft17
# 200.0     85
# 240.0     71
# 300.0     49
# 400.0     37
# 360.0     34
#           ..
# 1113.0     1
# 913.0      1
# 415.0      1
# 1111.0     1
# 201.0      1
# Name: yardbuildingsqft17, Length: 504, dtype: int64
# yardbuildingsqft26
# 120.0    3
# 56.0     2
# 300.0    2
# 240.0    2
# 448.0    2
# 196.0    1
# 140.0    1
# 48.0     1
# 284.0    1
# 39.0     1
# 133.0    1
# 486.0    1
# 250.0    1
# 91.0     1
# 491.0    1
# 16.0     1
# 204.0    1
# 71.0     1
# 28.0     1
# 195.0    1
# 292.0    1
# 231.0    1
# 30.0     1
# 320.0    1
# 384.0    1
# 180.0    1
# 49.0     1
# 868.0    1
# 462.0    1
# 461.0    1
# 368.0    1
# 105.0    1
# 37.0     1
# 88.0     1
# 160.0    1
# 45.0     1
# 752.0    1
# 169.0    1
# 21.0     1
# 200.0    1
# 113.0    1
# 41.0     1
# 314.0    1
# 12.0     1
# 414.0    1
# 66.0     1
# 648.0    1
# 174.0    1
# 218.0    1
# 60.0     1
# 336.0    1
# 108.0    1
# 144.0    1
# 216.0    1
# 360.0    1
# 72.0     1
# 576.0    1
# Name: yardbuildingsqft26, dtype: int64
# yearbuilt
# 1955.0    1893
# 1950.0    1605
# 1954.0    1513
# 1953.0    1481
# 1956.0    1384
#           ...
# 1892.0       1
# 1878.0       1
# 1882.0       1
# 1894.0       1
# 1880.0       1
# Name: yearbuilt, Length: 133, dtype: int64
# numberofstories
# 1.0    8868
# 2.0    5312
# 3.0     351
# 6.0       1
# Name: numberofstories, dtype: int64
# fireplaceflag
# 1.0    81
# Name: fireplaceflag, dtype: int64
# structuretaxvaluedollarcnt
# 100000.0    50
# 200000.0    36
# 90000.0     32
# 32489.0     28
# 95000.0     27
#             ..
# 156624.0     1
# 76353.0      1
# 68884.0      1
# 259627.0     1
# 32797.0      1
# Name: structuretaxvaluedollarcnt, Length: 37333, dtype: int64
# taxvaluedollarcnt
# 455000.0    33
# 600000.0    30
# 500000.0    24
# 550000.0    24
# 450000.0    24
#             ..
# 690763.0     1
# 379764.0     1
# 317155.0     1
# 155695.0     1
# 49546.0      1
# Name: taxvaluedollarcnt, Length: 38942, dtype: int64
# assessmentyear
# 2016.0    52320
# Name: assessmentyear, dtype: int64
# landtaxvaluedollarcnt
# 21299.0     95
# 22755.0     63
# 30210.0     63
# 16522.0     53
# 16749.0     51
#             ..
# 86973.0      1
# 499170.0     1
# 250803.0     1
# 122033.0     1
# 283704.0     1
# Name: landtaxvaluedollarcnt, Length: 36912, dtype: int64
# taxamount
# 345.72     4
# 2914.16    3
# 1404.44    3
# 955.88     3
# 4012.74    3
#           ..
# 1043.94    1
# 6526.81    1
# 2821.20    1
# 4626.40    1
# 6317.15    1
# Name: taxamount, Length: 50834, dtype: int64
# taxdelinquencyflag
# Y    2068
# Name: taxdelinquencyflag, dtype: int64
# taxdelinquencyyear
# 15.0    1124
# 14.0     559
# 13.0     126
# 12.0      81
# 11.0      79
# 10.0      47
# 9.0       33
# 8.0        8
# 7.0        8
# 6.0        1
# 99.0       1
# 4.0        1
# Name: taxdelinquencyyear, dtype: int64
# censustractandblock
# 6.037920e+13    32
# 6.037920e+13    27
# 6.037142e+13    24
# 6.059032e+13    24
# 6.059032e+13    23
#                 ..
# 6.037534e+13     1
# 6.037293e+13     1
# 6.037140e+13     1
# 6.037577e+13     1
# 6.037503e+13     1
# Name: censustractandblock, Length: 31404, dtype: int64
# logerror
#  0.002652    5
#  0.000231    5
#  0.001878    5
#  0.000727    5
#  0.000420    4
#             ..
# -0.004860    1
#  0.092613    1
# -0.049655    1
# -0.111529    1
#  0.037129    1
# Name: logerror, Length: 52061, dtype: int64
# transactiondate
# 2017-06-30    809
# 2017-04-28    614
# 2017-05-31    565
# 2017-07-28    546
# 2017-08-31    528
#              ...
# 2017-05-07      1
# 2017-05-13      1
# 2017-05-20      1
# 2017-06-11      1
# 2017-09-25      1
# Name: transactiondate, Length: 257, dtype: int64

# %%
# nulls by columns
df.isnull().head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0     False                   True                      True          True
# 1     False                   True                      True          True
# 2     False                   True                      True          True
# 3     False                   True                      True          True
# 4     False                  False                      True          True
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0        False       False                 True                   True
# 1        False       False                 True                   True
# 2        False       False                 True                   True
# 3        False       False                 True                  False
# 4        False       False                 True                  False
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# 0              False        True                      True
# 1              False        True                     False
# 2              False        True                      True
# 3              False        True                      True
# 4              False        True                      True
#
#    calculatedfinishedsquarefeet  finishedsquarefeet12  finishedsquarefeet13  \
# 0                         False                 False                  True
# 1                         False                 False                  True
# 2                         False                 False                  True
# 3                         False                 False                  True
# 4                         False                 False                  True
#
#    finishedsquarefeet15  finishedsquarefeet50  finishedsquarefeet6   fips  \
# 0                  True                  True                 True  False
# 1                  True                 False                 True  False
# 2                  True                  True                 True  False
# 3                  True                  True                 True  False
# 4                  True                  True                 True  False
#
#    fireplacecnt  fullbathcnt  garagecarcnt  garagetotalsqft  hashottuborspa  \
# 0          True        False         False            False            True
# 1         False        False         False            False            True
# 2          True        False         False            False            True
# 3          True        False          True             True            True
# 4          True        False          True             True            True
#
#    heatingorsystemtypeid  latitude  longitude  lotsizesquarefeet  poolcnt  \
# 0                   True     False      False              False     True
# 1                   True     False      False              False     True
# 2                   True     False      False              False    False
# 3                  False     False      False              False    False
# 4                  False     False      False              False    False
#
#    poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# 0         True          True         True         True
# 1         True          True         True         True
# 2         True          True         True        False
# 3         True          True         True        False
# 4         True          True         True        False
#
#    propertycountylandusecode  propertylandusetypeid  propertyzoningdesc  \
# 0                      False                  False                True
# 1                      False                  False                True
# 2                      False                  False                True
# 3                      False                  False               False
# 4                      False                  False               False
#
#    rawcensustractandblock  regionidcity  regionidcounty  regionidneighborhood  \
# 0                   False         False           False                  True
# 1                   False         False           False                  True
# 2                   False         False           False                  True
# 3                   False         False           False                  True
# 4                   False         False           False                 False
#
#    regionidzip  roomcnt  storytypeid  threequarterbathnbr  \
# 0        False    False         True                False
# 1        False    False         True                 True
# 2        False    False         True                 True
# 3        False    False         True                 True
# 4        False    False         True                 True
#
#    typeconstructiontypeid  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 0                    True     True                True                True
# 1                    True     True                True                True
# 2                    True     True                True                True
# 3                    True    False                True                True
# 4                    True    False                True                True
#
#    yearbuilt  numberofstories  fireplaceflag  structuretaxvaluedollarcnt  \
# 0      False             True           True                       False
# 1      False            False           True                       False
# 2      False            False           True                       False
# 3      False             True           True                       False
# 4      False             True           True                       False
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0              False           False                  False      False
# 1              False           False                  False      False
# 2              False           False                  False      False
# 3              False           False                  False      False
# 4              False           False                  False      False
#
#    taxdelinquencyflag  taxdelinquencyyear  censustractandblock  logerror  \
# 0                True                True                False     False
# 1                True                True                False     False
# 2                True                True                False     False
# 3                True                True                False     False
# 4                True                True                False     False
#
#    transactiondate
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %%
null_col = pd.DataFrame({'num_rows_missing': df.isnull().sum(),
                        'pct_rows_missing': (df.isnull().sum()/ df.shape[0])})
null_col.head()
# Out:
#                           num_rows_missing  pct_rows_missing
# parcelid                                 0          0.000000
# airconditioningtypeid                38705          0.739774
# architecturalstyletypeid             52250          0.998662
# basementsqft                         52273          0.999102
# bathroomcnt                              0          0.000000

# %% [markdown]
# # Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values.

# %%
def nulls_by_col(df):
    num_missing= df.isnull().sum()
    rows= df.shape[0]
    pct_missing = num_missing / rows
    cols_missing = pd.DataFrame({'num_rows_missing':num_missing,'pct_rows_missing':pct_missing})
                                
    return cols_missing.sort_values(by='num_rows_missing',ascending=False)

# %%
nulls_by_col(df).head()
# Out:
#                       num_rows_missing  pct_rows_missing
# buildingclasstypeid              77399          0.999806
# finishedsquarefeet13             77373          0.999470
# basementsqft                     77364          0.999354
# storytypeid                      77364          0.999354
# yardbuildingsqft26               77344          0.999096

# %% [markdown]
# # 4. Write a function that takes in a dataframe and returns a dataframe with 3 columns: the number of columns missing, percent of columns missing, and number of rows with n columns missing. Run the function and document takeaways from this on how you want to handle missing values.

# %%
def nulls_by_rows(df):
    
    num_missing= (df.isnull().sum(axis=1))
    pct_missing = num_missing / df.shape[1]
    rows_missing = pd.DataFrame({'num_rows_missimg':'num_cols_missing': num_missing, 'percent_cols_missing': pct_missing,'num_rows_missimg':})
    
    return rows_missing.sort_values(by='num_cols_missing', ascending=False)

# %%
nulls_by_rows(df)
# Out:
#        num_cols_missing  percent_cols_missing
# 40789                57              0.950000
# 19758                57              0.950000
# 388                  57              0.950000
# 64308                57              0.950000
# 8888                 57              0.950000
# ...                 ...                   ...
# 9659                 20              0.333333
# 62437                20              0.333333
# 54572                20              0.333333
# 18965                19              0.316667
# 15570                19              0.316667
#
# [77414 rows x 2 columns]

# %% [markdown]
# # Mall  customers

# %%
# ACQUIRE mall data from server
sql= '''Select * from customers'''

# %%
df= pd.read_sql(sql,get_connection('mall_customers'))
df.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40

# %%
#summarize
df.describe()
# Out:
#        customer_id         age  annual_income  spending_score
# count   200.000000  200.000000     200.000000      200.000000
# mean    100.500000   38.850000      60.560000       50.200000
# std      57.879185   13.969007      26.264721       25.823522
# min       1.000000   18.000000      15.000000        1.000000
# 25%      50.750000   28.750000      41.500000       34.750000
# 50%     100.500000   36.000000      61.500000       50.000000
# 75%     150.250000   49.000000      78.000000       73.000000
# max     200.000000   70.000000     137.000000       99.000000

# %%
# check nulls
df.isna().sum()
# Out:
# customer_id       0
# gender            0
# age               0
# annual_income     0
# spending_score    0
# dtype: int64

# %% [markdown]
# ### Outliers using IQR

# %%
# age quantiles
q1, q3 = df['age'].quantile([.25,.75])
q1, q3
# Out:
# (28.75, 49.0)

# %%
# calculating IQR
age_iqr = q3-q1
age_iqr
# Out:
# 20.25

# %%
# upperbound and lower bound with k =1.5
upper = q3 +(age_iqr * 1.5)
lower = q1 - (age_iqr * 1.5)

upper, lower
# Out:
# (79.375, -1.625)

# %%
# confirming age outliers has been handled
df[df.age> upper]
# Out:
# Empty DataFrame
# Columns: [customer_id, gender, age, annual_income, spending_score]
# Index: []

# %%
# splitting the data into train, test and validate
seed = 123

train, test_val = train_test_split(df, train_size=0.7,
                                   random_state=seed)

test, val = train_test_split(test_val, train_size=0.5,
                                       random_state=seed)

train.shape, val.shape, test.shape
# Out:
# ((140, 5), (30, 5), (30, 5))

# %%
# encoding categorical column using pd.get_dummies
train =pd.get_dummies(train,drop_first= True)
train.head()
# Out:
#      customer_id  age  annual_income  spending_score  gender_Male
# 81            82   38             54              55            1
# 107          108   54             63              46            1
# 112          113   38             64              42            0
# 145          146   28             77              97            1
# 8              9   64             19               3            1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140 entries, 81 to 109
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     140 non-null    int64
#  1   age             140 non-null    int64
#  2   annual_income   140 non-null    int64
#  3   spending_score  140 non-null    int64
#  4   gender_Male     140 non-null    uint8
# dtypes: int64(4), uint8(1)
# memory usage: 5.6 KB

# %%
# scale the data. columns to scale age and annual income using minmaxsclaer
scaler= MinMaxScaler()
train[['age','annual_income']]= scaler.fit_transform(train[['age','annual_income']])
train.head()
# Out:
#      customer_id       age  annual_income  spending_score  gender_Male
# 81            82  0.384615       0.319672              55            1
# 107          108  0.692308       0.393443              46            1
# 112          113  0.384615       0.401639              42            0
# 145          146  0.192308       0.508197              97            1
# 8              9  0.884615       0.032787               3            1
